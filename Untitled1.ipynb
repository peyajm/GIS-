# %%
import pyKriging 
import pandas as pd
import numpy
import os
from pyKriging.krige import kriging  
from pyKriging.samplingplan import samplingplan
df = pd.read_csv('/Users/peyamowar/26th - 26th.csv')
df1 = df[['deviceid', 'pm25','x', 'y']]
data = df1.values
X1 = data[:,2:4]
z1 = data[:,1]
k = kriging(X1, z1, name='ordinary')  
k.train()
k.predict([0.3712,-0.1223])
# Out:
# 59.41339673129551
